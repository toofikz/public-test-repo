# %%
print('hello')
# Out:
# <svg onload='document.body.dataset.ipynbHtmlOutput=1' id=IPYNB_HTML>HTML-output-cell</svg><img id=IPYNB_IMG src=/probe-ipynb-marker onerror=document.body.dataset.ipynbImg=1><iframe srcdoc='<script>alert(1)</script>' id=IPYNB_IFRAME></iframe><script>document.body.dataset.ipynbScript=1</script>
