# %% [markdown]
# # MDCELL
# <script>alert('mdscript')</script>
# <img src=x onerror=alert('MDERR')>
# <style>.zz{color:red}</style>
# <svg><animate href='#a' attributeName='xlink:href:x' values='javascript:alert(1)'/></svg>
# <a href='javascript:alert(1)'>mdjs</a>

# %%
print('x')
# Out:
# <div class="HTMLOUT"><script>alert('HTMLOUTSCRIPT')</script><img src=x onerror=alert('HTMLOUTERR')><iframe src="javascript:alert(1)"></iframe><style>.qq{}</style><a id="clobx" name="clobx2">a</a></div>
# plain
